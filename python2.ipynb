# %% [markdown]
# Importando bibliotecas

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import glob

# %% [markdown]
# Definindo variáveis

# %%
glob.glob ('*txt')
arquivos = glob.glob('dados/*.txt')
print(arquivos)
# Out:
# ['dados\\0.80S-49.02W-TAVG-Trend.txt', 'dados\\10.45S-48.27W-TAVG-Trend.txt', 'dados\\13.66S-38.81W-TAVG-Trend.txt', 'dados\\15.27S-47.50W-TAVG-Trend.txt', 'dados\\2.41S-60.27W-TAVG-Trend.txt', 'dados\\20.09S-44.36W-TAVG-Trend.txt', 'dados\\20.09S-54.60W-TAVG-Trend.txt', 'dados\\23.31S-42.82W-TAVG-Trend.txt', 'dados\\23.31S-46.31W-TAVG-Trend.txt', 'dados\\24.92S-49.66W-TAVG-Trend.txt', 'dados\\29.74S-51.69W-TAVG-Trend.txt', 'dados\\4.02S-40.98W-TAVG-Trend.txt', 'dados\\brazil-TAVG-Trend.txt']

# %%
for nome_arquivo in arquivos:
    if nome_arquivo != "dados\\brazil-TAVG-Trend.txt":
        t=np.loadtxt(nome_arquivo,comments='%')
        Anos = t[:, 0]
        anomalia_anual = t[:,5]
        plt.figure ()
        plt.plot (Anos, 25 + anomalia_anual, c ='#0000FF')
        plt.xlabel ("Anos")
        plt.ylabel ("Temperatura em Cº")
        plt.title (nome_arquivo)
        plt.savefig

# %%
lis=[0,1,2,3,4,5,6]
b=0
for i in lis:
    print(i)
    print(i+2)
# Out:
# 0
# 2
# 1
# 3
# 2
# 4
# 3
# 5
# 4
# 6
# 5
# 7
# 6
# 8

# %%
t=np.loadtxt(nome_arquivo,comments='%')

# %%
for nome_arquivo in dados:
    print(nome_arquivo)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-2d4d1e251c85> in <module>()
# ----> 1 for nome_arquivo in dados:
#       2     print(nome_arquivo)
#
# NameError: name 'dados' is not defined

# %%
dados = np.loadtxt ("dados/*txt", comments="%")
print(dados)
# Out:
# [[  1.83200000e+03   1.00000000e+00  -5.75000000e-01 ...,              nan
#                nan              nan]
#  [  1.83200000e+03   2.00000000e+00  -1.00500000e+00 ...,              nan
#                nan              nan]
#  [  1.83200000e+03   3.00000000e+00  -7.93000000e-01 ...,              nan
#                nan              nan]
#  ...,
#  [  2.01300000e+03   7.00000000e+00   7.72000000e-01 ...,              nan
#                nan              nan]
#  [  2.01300000e+03   8.00000000e+00   1.86000000e-01 ...,              nan
#                nan              nan]
#  [  2.01300000e+03   9.00000000e+00              nan ...,              nan
#                nan              nan]]

# %%
Anos = dados[:, 0]
print (Anos)
# Out:
# [ 1832.  1832.  1832. ...,  2013.  2013.  2013.]

# %%
anomalia_temperaturas = dados[:, 4]
print (anomalia_temperaturas)
# Out:
# [ nan  nan  nan ...,  nan  nan  nan]
